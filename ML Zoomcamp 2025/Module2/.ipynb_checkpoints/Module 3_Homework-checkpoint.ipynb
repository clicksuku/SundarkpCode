# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('course_lead_scoring.csv')

# %%
df.head()
# Out:
#     lead_source    industry  number_of_courses_viewed  annual_income  \
# 0      paid_ads         NaN                         1        79450.0
# 1  social_media      retail                         1        46992.0
# 2        events  healthcare                         5        78796.0
# 3      paid_ads      retail                         2        83843.0
# 4      referral   education                         3        85012.0
#
#   employment_status       location  interaction_count  lead_score  converted
# 0        unemployed  south_america                  4        0.94          1
# 1          employed  south_america                  1        0.80          0
# 2        unemployed      australia                  3        0.69          1
# 3               NaN      australia                  1        0.87          0
# 4     self_employed         europe                  3        0.62          1

# %%
df['industry'].mode()
# Out:
# 0    retail
# Name: industry, dtype: object

# %%
df.dtypes
# Out:
# lead_source                  object
# industry                     object
# number_of_courses_viewed      int64
# annual_income               float64
# employment_status            object
# location                     object
# interaction_count             int64
# lead_score                  float64
# converted                     int64
# dtype: object

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

# %%
categorical = list(df.dtypes[df.dtypes == 'object'].index)
categorical
# Out:
# ['lead_source', 'industry', 'employment_status', 'location']

# %%
numerical = ['number_of_courses_viewed', 'annual_income', 'interaction_count', 'lead_score', 'converted']

# %%
df[numerical]
# Out:
#       number_of_courses_viewed  annual_income  interaction_count  lead_score  \
# 0                            1        79450.0                  4        0.94
# 1                            1        46992.0                  1        0.80
# 2                            5        78796.0                  3        0.69
# 3                            2        83843.0                  1        0.87
# 4                            3        85012.0                  3        0.62
# ...                        ...            ...                ...         ...
# 1457                         1            NaN                  4        0.53
# 1458                         3        65259.0                  2        0.24
# 1459                         1        45688.0                  3        0.02
# 1460                         5        71016.0                  0        0.25
# 1461                         3        92855.0                  3        0.41
#
#       converted
# 0             1
# 1             0
# 2             1
# 3             0
# 4             1
# ...         ...
# 1457          1
# 1458          1
# 1459          1
# 1460          1
# 1461          1
#
# [1462 rows x 5 columns]

# %%
for c in categorical_columns:
    df[c] = df[c].str.lower().str.replace(' ', '_')

# %%
df.head().T
# Out:
#                                       0              1           2          3  \
# lead_source                    paid_ads   social_media      events   paid_ads
# industry                            NaN         retail  healthcare     retail
# number_of_courses_viewed              1              1           5          2
# annual_income                   79450.0        46992.0     78796.0    83843.0
# employment_status            unemployed       employed  unemployed        NaN
# location                  south_america  south_america   australia  australia
# interaction_count                     4              1           3          1
# lead_score                         0.94            0.8        0.69       0.87
# converted                             1              0           1          0
#
#                                       4
# lead_source                    referral
# industry                      education
# number_of_courses_viewed              3
# annual_income                   85012.0
# employment_status         self_employed
# location                         europe
# interaction_count                     3
# lead_score                         0.62
# converted                             1

# %%
df=df.fillna(0)

# %%
from sklearn.model_selection import train_test_split

# %%
df_full_train, df_test = train_test_split(df, test_size=0.2, random_state=1)
df_train, df_val = train_test_split(df_full_train, test_size=0.25, random_state=1)

# %%
len(df_train), len(df_val), len(df_test)
# Out:
# (876, 293, 293)

# %%
df_test.head()
# Out:
#         lead_source    industry  number_of_courses_viewed  annual_income  \
# 719  organic_search  technology                         1            0.0
# 683        paid_ads     finance                         1        47129.0
# 503               0   education                         0            0.0
# 424          events      retail                         0        64775.0
# 846    social_media     finance                         3        46934.0
#
#     employment_status       location  interaction_count  lead_score  converted
# 719          employed    middle_east                  2        0.90          0
# 683                 0  south_america                  1        0.93          0
# 503        unemployed           asia                  5        0.97          1
# 424     self_employed  south_america                  3        0.70          1
# 846                 0      australia                  3        0.26          1

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
y_train = df_train.lead_score.values
y_val = df_val.lead_score.values
y_test = df_test.lead_score.values

# %%
del df_train['lead_score']
del df_val['lead_score']
del df_test['lead_score']

# %%
df_full_train.isnull().sum()
# Out:
# lead_source                 0
# industry                    0
# number_of_courses_viewed    0
# annual_income               0
# employment_status           0
# location                    0
# interaction_count           0
# lead_score                  0
# converted                   0
# dtype: int64

# %%
df_full_train.lead_score.value_counts(normalize=True)
# Out:
# lead_score
# 0.60    0.019675
# 0.66    0.015398
# 0.20    0.015398
# 0.88    0.014542
# 0.92    0.014542
#           ...
# 0.58    0.005988
# 0.74    0.005988
# 0.00    0.005133
# 1.00    0.004277
# 0.80    0.003422
# Name: proportion, Length: 101, dtype: float64

# %%
from IPython.display import display

# %%
global_lead_score = df['lead_score'].mean()

# %%
global_lead_score
# Out:
# 0.506108071135431

# %%
for c in categorical:
    print(c)
    df_group = df_full_train.groupby(c).lead_score.agg(['mean', 'count'])
    df_group['diff'] = df_group['mean'] - global_lead_score
    df_group['risk'] = df_group['mean'] / global_lead_score
    display(df_group)
    print()
# Out:
# lead_source
#                     mean  count      diff      risk
# lead_source
# 0               0.503711     97 -0.002397  0.995264
# events          0.496458    192 -0.009650  0.980933
# organic_search  0.464957    230 -0.041152  0.918690
# paid_ads        0.501262    214 -0.004846  0.990424
# referral        0.516165    206  0.010057  1.019871
# social_media    0.515304    230  0.009196  1.018171
# industry
#                    mean  count      diff      risk
# industry
# 0              0.477434    113 -0.028674  0.943343
# education      0.550510    157  0.044401  1.087731
# finance        0.482194    155 -0.023915  0.952748
# healthcare     0.512708    144  0.006600  1.013041
# manufacturing  0.484503    151 -0.021605  0.957312
# other          0.481026    156 -0.025082  0.950441
# retail         0.511437    160  0.005329  1.010530
# technology     0.483158    133 -0.022950  0.954654
# employment_status
#                        mean  count      diff      risk
# employment_status
# 0                  0.522740     73  0.016632  1.032862
# employed           0.476447    273 -0.029661  0.941394
# self_employed      0.474291    275 -0.031817  0.937134
# student            0.483854    288 -0.022254  0.956029
# unemployed         0.558577    260  0.052469  1.103671
# location
#                    mean  count      diff      risk
# location
# 0              0.524600     50  0.018492  1.036538
# africa         0.551946    149  0.045838  1.090570
# asia           0.467351    151 -0.038757  0.923421
# australia      0.463108    148 -0.043000  0.915038
# europe         0.517045    176  0.010937  1.021611
# middle_east    0.516815    157  0.010707  1.021156
# north_america  0.473172    186 -0.032936  0.934923
# south_america  0.496776    152 -0.009332  0.981562

# %%
for c in numerical:
    print(c)
    df_group = df_full_train.groupby(c).lead_score.agg(['mean', 'count'])
    df_group['diff'] = df_group['mean'] - global_lead_score
    df_group['risk'] = df_group['mean'] / global_lead_score
    display(df_group)
    print()
# Out:
# number_of_courses_viewed
#                               mean  count      diff      risk
# number_of_courses_viewed
# 0                         0.493819    144 -0.012289  0.975719
# 1                         0.516667    330  0.010559  1.020862
# 2                         0.495333    315 -0.010775  0.978711
# 3                         0.488654    208 -0.017454  0.965513
# 4                         0.462903     93 -0.043205  0.914633
# 5                         0.485385     52 -0.020723  0.959053
# 6                         0.576500     20  0.070392  1.139085
# 7                         0.542500      4  0.036392  1.071905
# 8                         0.655000      2  0.148892  1.294190
# 9                         0.660000      1  0.153892  1.304069
# annual_income
#                 mean  count      diff      risk
# annual_income
# 0.0            0.475    142 -0.031108  0.938535
# 13929.0        0.690      1  0.183892  1.363345
# 16132.0        0.470      1 -0.036108  0.928655
# 16351.0        0.330      1 -0.176108  0.652035
# 17735.0        0.350      1 -0.156108  0.691552
# ...              ...    ...       ...       ...
# 101567.0       0.360      1 -0.146108  0.711311
# 101908.0       0.490      1 -0.016108  0.968173
# 102742.0       0.050      1 -0.456108  0.098793
# 102855.0       0.430      1 -0.076108  0.849621
# 109899.0       0.410      1 -0.096108  0.810104
#
# [1017 rows x 4 columns]
# interaction_count
#                        mean  count      diff      risk
# interaction_count
# 0                  0.497213     61 -0.008895  0.982425
# 1                  0.493512    168 -0.012596  0.975112
# 2                  0.500313    256 -0.005796  0.988549
# 3                  0.491439    278 -0.014669  0.971016
# 4                  0.519495    218  0.013387  1.026452
# 5                  0.453714    105 -0.052394  0.896477
# 6                  0.522449     49  0.016341  1.032287
# 7                  0.583704     27  0.077596  1.153318
# 8                  0.505000      4 -0.001108  0.997811
# 9                  0.475000      2 -0.031108  0.938535
# 10                 0.080000      1 -0.426108  0.158069
# lead_score
#             mean  count      diff      risk
# lead_score
# 0.00        0.00      6 -0.506108  0.000000
# 0.01        0.01     13 -0.496108  0.019759
# 0.02        0.02     16 -0.486108  0.039517
# 0.03        0.03     11 -0.476108  0.059276
# 0.04        0.04     12 -0.466108  0.079035
# ...          ...    ...       ...       ...
# 0.96        0.96     14  0.453892  1.896828
# 0.97        0.97     10  0.463892  1.916587
# 0.98        0.98     16  0.473892  1.936345
# 0.99        0.99      8  0.483892  1.956104
# 1.00        1.00      5  0.493892  1.975863
#
# [101 rows x 4 columns]
# converted
#                mean  count      diff      risk
# converted
# 0          0.428084    454 -0.078024  0.845835
# 1          0.543902    715  0.037794  1.074676

# %%
combined_list = numerical + categorical
for c in combined_list:
    print(c)
    df_group = df_full_train.groupby(c).lead_score.agg(['mean', 'count'])
    df_group['diff'] = df_group['mean'] - global_lead_score
    df_group['risk'] = df_group['mean'] / global_lead_score
    display(df_group)
    print()
# Out:
# number_of_courses_viewed
#                               mean  count      diff      risk
# number_of_courses_viewed
# 0                         0.493819    144 -0.012289  0.975719
# 1                         0.516667    330  0.010559  1.020862
# 2                         0.495333    315 -0.010775  0.978711
# 3                         0.488654    208 -0.017454  0.965513
# 4                         0.462903     93 -0.043205  0.914633
# 5                         0.485385     52 -0.020723  0.959053
# 6                         0.576500     20  0.070392  1.139085
# 7                         0.542500      4  0.036392  1.071905
# 8                         0.655000      2  0.148892  1.294190
# 9                         0.660000      1  0.153892  1.304069
# annual_income
#                 mean  count      diff      risk
# annual_income
# 0.0            0.475    142 -0.031108  0.938535
# 13929.0        0.690      1  0.183892  1.363345
# 16132.0        0.470      1 -0.036108  0.928655
# 16351.0        0.330      1 -0.176108  0.652035
# 17735.0        0.350      1 -0.156108  0.691552
# ...              ...    ...       ...       ...
# 101567.0       0.360      1 -0.146108  0.711311
# 101908.0       0.490      1 -0.016108  0.968173
# 102742.0       0.050      1 -0.456108  0.098793
# 102855.0       0.430      1 -0.076108  0.849621
# 109899.0       0.410      1 -0.096108  0.810104
#
# [1017 rows x 4 columns]
# interaction_count
#                        mean  count      diff      risk
# interaction_count
# 0                  0.497213     61 -0.008895  0.982425
# 1                  0.493512    168 -0.012596  0.975112
# 2                  0.500313    256 -0.005796  0.988549
# 3                  0.491439    278 -0.014669  0.971016
# 4                  0.519495    218  0.013387  1.026452
# 5                  0.453714    105 -0.052394  0.896477
# 6                  0.522449     49  0.016341  1.032287
# 7                  0.583704     27  0.077596  1.153318
# 8                  0.505000      4 -0.001108  0.997811
# 9                  0.475000      2 -0.031108  0.938535
# 10                 0.080000      1 -0.426108  0.158069
# lead_score
#             mean  count      diff      risk
# lead_score
# 0.00        0.00      6 -0.506108  0.000000
# 0.01        0.01     13 -0.496108  0.019759
# 0.02        0.02     16 -0.486108  0.039517
# 0.03        0.03     11 -0.476108  0.059276
# 0.04        0.04     12 -0.466108  0.079035
# ...          ...    ...       ...       ...
# 0.96        0.96     14  0.453892  1.896828
# 0.97        0.97     10  0.463892  1.916587
# 0.98        0.98     16  0.473892  1.936345
# 0.99        0.99      8  0.483892  1.956104
# 1.00        1.00      5  0.493892  1.975863
#
# [101 rows x 4 columns]
# converted
#                mean  count      diff      risk
# converted
# 0          0.428084    454 -0.078024  0.845835
# 1          0.543902    715  0.037794  1.074676
# lead_source
#                     mean  count      diff      risk
# lead_source
# 0               0.503711     97 -0.002397  0.995264
# events          0.496458    192 -0.009650  0.980933
# organic_search  0.464957    230 -0.041152  0.918690
# paid_ads        0.501262    214 -0.004846  0.990424
# referral        0.516165    206  0.010057  1.019871
# social_media    0.515304    230  0.009196  1.018171
# industry
#                    mean  count      diff      risk
# industry
# 0              0.477434    113 -0.028674  0.943343
# education      0.550510    157  0.044401  1.087731
# finance        0.482194    155 -0.023915  0.952748
# healthcare     0.512708    144  0.006600  1.013041
# manufacturing  0.484503    151 -0.021605  0.957312
# other          0.481026    156 -0.025082  0.950441
# retail         0.511437    160  0.005329  1.010530
# technology     0.483158    133 -0.022950  0.954654
# employment_status
#                        mean  count      diff      risk
# employment_status
# 0                  0.522740     73  0.016632  1.032862
# employed           0.476447    273 -0.029661  0.941394
# self_employed      0.474291    275 -0.031817  0.937134
# student            0.483854    288 -0.022254  0.956029
# unemployed         0.558577    260  0.052469  1.103671
# location
#                    mean  count      diff      risk
# location
# 0              0.524600     50  0.018492  1.036538
# africa         0.551946    149  0.045838  1.090570
# asia           0.467351    151 -0.038757  0.923421
# australia      0.463108    148 -0.043000  0.915038
# europe         0.517045    176  0.010937  1.021611
# middle_east    0.516815    157  0.010707  1.021156
# north_america  0.473172    186 -0.032936  0.934923
# south_america  0.496776    152 -0.009332  0.981562

# %%
def mutual_info_lead_score(series):
    return mutual_info_score(series, df_full_train.lead_score)

# %%
from sklearn.metrics import mutual_info_score

# %%
mi = df_full_train[categorical].apply(mutual_info_lead_score)
mi.sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 mi = df_full_train[categorical].apply(mutual_info_lead_score)
#       2 mi.sort_values(ascending=False)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py:10034, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, **kwargs)
#   10022 from pandas.core.apply import frame_apply
#   10024 op = frame_apply(
#   10025     self,
#   10026     func=func,
#    (...)  10032     kwargs=kwargs,
#   10033 )
# > 10034 return op.apply().__finalize__(self, method="apply")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/apply.py:837, in FrameApply.apply(self)
#     834 elif self.raw:
#     835     return self.apply_raw()
# --> 837 return self.apply_standard()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/apply.py:965, in FrameApply.apply_standard(self)
#     964 def apply_standard(self):
# --> 965     results, res_index = self.apply_series_generator()
#     967     # wrap results
#     968     return self.wrap_results(results, res_index)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/apply.py:981, in FrameApply.apply_series_generator(self)
#     978 with option_context("mode.chained_assignment", None):
#     979     for i, v in enumerate(series_gen):
#     980         # ignore SettingWithCopy here in case the user mutates
# --> 981         results[i] = self.func(v, *self.args, **self.kwargs)
#     982         if isinstance(results[i], ABCSeries):
#     983             # If we have a view on v, we need to make a copy because
#     984             #  series_generator will swap out the underlying data
#     985             results[i] = results[i].copy(deep=False)
#
# Cell In[80], line 2, in mutual_info_lead_score(series)
#       1 def mutual_info_lead_score(series):
# ----> 2     return mutual_info_score(series, df_full_train.lead_score)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
#     219     # the function to delegate validation to the estimator, but we replace
#     220     # the name of the estimator by the name of the function in the error
#     221     # message to avoid confusion.
#     222     msg = re.sub(
#     223         r"parameter of \w+ must be",
#     224         f"parameter of {func.__qualname__} must be",
#     225         str(e),
#     226     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/cluster/_supervised.py:885, in mutual_info_score(labels_true, labels_pred, contingency)
#     819 """Mutual Information between two clusterings.
#     820
#     821 The Mutual Information is a measure of the similarity between two labels
#    (...)    882 np.float64(0.056...)
#     883 """
#     884 if contingency is None:
# --> 885     labels_true, labels_pred = check_clusterings(labels_true, labels_pred)
#     886     contingency = contingency_matrix(labels_true, labels_pred, sparse=True)
#     887 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/cluster/_supervised.py:50, in check_clusterings(labels_true, labels_pred)
#      36 labels_true = check_array(
#      37     labels_true,
#      38     ensure_2d=False,
#      39     ensure_min_samples=0,
#      40     dtype=None,
#      41 )
#      43 labels_pred = check_array(
#      44     labels_pred,
#      45     ensure_2d=False,
#      46     ensure_min_samples=0,
#      47     dtype=None,
#      48 )
# ---> 50 type_label = type_of_target(labels_true)
#      51 type_pred = type_of_target(labels_pred)
#      53 if "continuous" in (type_pred, type_label):
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:423, in type_of_target(y, input_name, raise_unknown)
#     421 if issparse(first_row_or_val):
#     422     first_row_or_val = first_row_or_val.data
# --> 423 if cached_unique(y).shape[0] > 2 or (y.ndim == 2 and len(first_row_or_val) > 1):
#     424     # [1, 2, 3] or [[1., 2., 3]] or [[1, 2]]
#     425     return "multiclass" + suffix
#     426 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/_unique.py:105, in cached_unique(xp, *ys)
#      81 def cached_unique(*ys, xp=None):
#      82     """Return the unique values of ys.
#      83
#      84     Use the cached values from dtype.metadata if present.
#    (...)    103         Unique values of ys.
#     104     """
# --> 105     res = tuple(_cached_unique(y, xp=xp) for y in ys)
#     106     if len(res) == 1:
#     107         return res[0]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/_unique.py:105, in <genexpr>(.0)
#      81 def cached_unique(*ys, xp=None):
#      82     """Return the unique values of ys.
#      83
#      84     Use the cached values from dtype.metadata if present.
#    (...)    103         Unique values of ys.
#     104     """
# --> 105     res = tuple(_cached_unique(y, xp=xp) for y in ys)
#     106     if len(res) == 1:
#     107         return res[0]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/_unique.py:78, in _cached_unique(y, xp)
#      76     pass
#      77 xp, _ = get_namespace(y, xp=xp)
# ---> 78 return xp.unique_values(y)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/_array_api.py:416, in _NumPyAPIWrapper.unique_values(self, x)
#     415 def unique_values(self, x):
# --> 416     return numpy.unique(x)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/lib/arraysetops.py:274, in unique(ar, return_index, return_inverse, return_counts, axis, equal_nan)
#     272 ar = np.asanyarray(ar)
#     273 if axis is None:
# --> 274     ret = _unique1d(ar, return_index, return_inverse, return_counts,
#     275                     equal_nan=equal_nan)
#     276     return _unpack_tuple(ret)
#     278 # axis was specified and not None
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/lib/arraysetops.py:336, in _unique1d(ar, return_index, return_inverse, return_counts, equal_nan)
#     334     aux = ar[perm]
#     335 else:
# --> 336     ar.sort()
#     337     aux = ar
#     338 mask = np.empty(aux.shape, dtype=np.bool_)
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
mutual_info_score(df_full_train.lead_score, df_full_train.employment_status)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 mutual_info_score(df_full_train.lead_score, df_full_train.employment_status)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
#     219     # the function to delegate validation to the estimator, but we replace
#     220     # the name of the estimator by the name of the function in the error
#     221     # message to avoid confusion.
#     222     msg = re.sub(
#     223         r"parameter of \w+ must be",
#     224         f"parameter of {func.__qualname__} must be",
#     225         str(e),
#     226     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/cluster/_supervised.py:885, in mutual_info_score(labels_true, labels_pred, contingency)
#     819 """Mutual Information between two clusterings.
#     820
#     821 The Mutual Information is a measure of the similarity between two labels
#    (...)    882 np.float64(0.056...)
#     883 """
#     884 if contingency is None:
# --> 885     labels_true, labels_pred = check_clusterings(labels_true, labels_pred)
#     886     contingency = contingency_matrix(labels_true, labels_pred, sparse=True)
#     887 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/cluster/_supervised.py:51, in check_clusterings(labels_true, labels_pred)
#      43 labels_pred = check_array(
#      44     labels_pred,
#      45     ensure_2d=False,
#      46     ensure_min_samples=0,
#      47     dtype=None,
#      48 )
#      50 type_label = type_of_target(labels_true)
# ---> 51 type_pred = type_of_target(labels_pred)
#      53 if "continuous" in (type_pred, type_label):
#      54     msg = (
#      55         "Clustering metrics expects discrete values but received"
#      56         f" {type_label} values for label, and {type_pred} values "
#      57         "for target"
#      58     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:423, in type_of_target(y, input_name, raise_unknown)
#     421 if issparse(first_row_or_val):
#     422     first_row_or_val = first_row_or_val.data
# --> 423 if cached_unique(y).shape[0] > 2 or (y.ndim == 2 and len(first_row_or_val) > 1):
#     424     # [1, 2, 3] or [[1., 2., 3]] or [[1, 2]]
#     425     return "multiclass" + suffix
#     426 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/_unique.py:105, in cached_unique(xp, *ys)
#      81 def cached_unique(*ys, xp=None):
#      82     """Return the unique values of ys.
#      83
#      84     Use the cached values from dtype.metadata if present.
#    (...)    103         Unique values of ys.
#     104     """
# --> 105     res = tuple(_cached_unique(y, xp=xp) for y in ys)
#     106     if len(res) == 1:
#     107         return res[0]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/_unique.py:105, in <genexpr>(.0)
#      81 def cached_unique(*ys, xp=None):
#      82     """Return the unique values of ys.
#      83
#      84     Use the cached values from dtype.metadata if present.
#    (...)    103         Unique values of ys.
#     104     """
# --> 105     res = tuple(_cached_unique(y, xp=xp) for y in ys)
#     106     if len(res) == 1:
#     107         return res[0]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/_unique.py:78, in _cached_unique(y, xp)
#      76     pass
#      77 xp, _ = get_namespace(y, xp=xp)
# ---> 78 return xp.unique_values(y)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/_array_api.py:416, in _NumPyAPIWrapper.unique_values(self, x)
#     415 def unique_values(self, x):
# --> 416     return numpy.unique(x)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/lib/arraysetops.py:274, in unique(ar, return_index, return_inverse, return_counts, axis, equal_nan)
#     272 ar = np.asanyarray(ar)
#     273 if axis is None:
# --> 274     ret = _unique1d(ar, return_index, return_inverse, return_counts,
#     275                     equal_nan=equal_nan)
#     276     return _unpack_tuple(ret)
#     278 # axis was specified and not None
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/lib/arraysetops.py:336, in _unique1d(ar, return_index, return_inverse, return_counts, equal_nan)
#     334     aux = ar[perm]
#     335 else:
# --> 336     ar.sort()
#     337     aux = ar
#     338 mask = np.empty(aux.shape, dtype=np.bool_)
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
df_train['employment_status'].unique()
# Out:
# array(['unemployed', 'student', 'employed', 'self_employed', 0],
#       dtype=object)
